# %%
# Import Required Libraries
Import the necessary libraries, including NumPy.
</VSCode.Cell>
<VSCode.Cell language="python">
import numpy as np
import matplotlib.pyplot as plt
</VSCode.Cell>
<VSCode.Cell language="markdown">
## Create Random Arrays
Use NumPy to create random arrays of various shapes and sizes, including 1D, 2D, and 3D arrays.
</VSCode.Cell>
<VSCode.Cell language="python">
arr1 = np.random.rand(5)
arr2 = np.random.rand(3,4)
arr3 = np.random.rand(2,3,4)
arr1, arr2, arr3
</VSCode.Cell>
<VSCode.Cell language="markdown">
## Seed the Random Number Generator
Use the seed() function to seed the random number generator for reproducibility.
</VSCode.Cell>
<VSCode.Cell language="python">
np.random.seed(42)
arr_seeded = np.random.rand(5)
arr_seeded
</VSCode.Cell>
<VSCode.Cell language="markdown">
## Generate Random Integers
Use the randint() function to generate random integers within a specified range.
</VSCode.Cell>
<VSCode.Cell language="python">
ints = np.random.randint(0, 10, size=(5,))
ints
</VSCode.Cell>
<VSCode.Cell language="markdown">
## Reshape and Manipulate Random Arrays
Demonstrate reshaping, transposing, and performing basic arithmetic operations on the random arrays.
</VSCode.Cell>
<VSCode.Cell language="python">
arr = np.random.rand(6)
arr2d = arr.reshape((2,3))
arr2d.T, arr2d * 2
</VSCode.Cell>
<VSCode.Cell language="markdown">
## Visualize Random Arrays
Use matplotlib or similar to plot histograms or heatmaps of the generated random data.
</VSCode.Cell>
<VSCode.Cell language="python">
plt.hist(np.random.randn(1000))
plt.show()
</VSCode.Cell>
<VSCode.Cell language="markdown">
## Save and Load Random Arrays
Show how to save arrays to disk with np.save and np.load and discuss formats like .npy and .npz.
</VSCode.Cell>
<VSCode.Cell language="python">
np.save('test_array.npy', arr)
loaded = np.load('test_array.npy')
loaded
